# %%
import os
import cv2
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

# ==== STEP 1: Load and preprocess images ==== Harsh
dataset_path = r"C:\Users\kunjc\Downloads\gas"
image_size = (64, 64)
X = []
brands = []
sizes = []

print("Loading data...")
for folder_name in os.listdir(dataset_path):
    folder_path = os.path.join(dataset_path, folder_name)
    if not os.path.isdir(folder_path):
        continue

    try:
        brand_label, size_label = folder_name.split("_")
    except ValueError:
        print("Skipping unknown label folder:", folder_name)
        continue

    for file in os.listdir(folder_path):
        if file.lower().endswith((".jpg", ".jpeg", ".png")):
            img_path = os.path.join(folder_path, file)
            try:
                img = cv2.imread(img_path)
                img = cv2.resize(img, image_size)
                img = img / 255.0  # normalize
                X.append(img)
                brands.append(0 if brand_label.upper() == "HP" else 1)
                sizes.append({"2KG": 0, "5KG": 1, "15KG": 2}[size_label.upper()])
            except:
                print("Error loading:", img_path)

X = np.array(X)
y_brand = to_categorical(np.array(brands), num_classes=2)
y_size = to_categorical(np.array(sizes), num_classes=3)

print("Total images loaded:", len(X))

# ==== STEP 2: Train-Test Split ====
X_train, X_val, yb_train, yb_val, ys_train, ys_val = train_test_split(
    X, y_brand, y_size, test_size=0.2, random_state=42
)

# ==== STEP 3: Data Augmentation ====
datagen = ImageDataGenerator(
    rotation_range=15,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

# ==== STEP 4: Build Improved CNN Model ====
input_layer = Input(shape=(64, 64, 3))

x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_layer)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Flatten()(x)
x = Dropout(0.5)(x)

brand_output = Dense(2, activation='softmax', name='brand_output')(x)
size_output = Dense(3, activation='softmax', name='size_output')(x)

model = Model(inputs=input_layer, outputs=[brand_output, size_output])

model.compile(
    optimizer='adam',
    loss={'brand_output': 'categorical_crossentropy', 'size_output': 'categorical_crossentropy'},
    metrics={'brand_output': 'accuracy', 'size_output': 'accuracy'}
)

model.summary()

# ==== STEP 5: Custom Multi-output Generator ====
def multi_output_generator(datagen, X, yb, ys, batch_size):
    gen = datagen.flow(X, yb, batch_size=batch_size, shuffle=True, seed=42)
    while True:
        xb, yb_batch = next(gen)
        idxs = np.random.choice(len(ys), size=len(xb), replace=False)
        ys_batch = ys[idxs]
        yield xb, {'brand_output': yb_batch, 'size_output': ys_batch}

batch_size = 32
train_gen = multi_output_generator(datagen, X_train, yb_train, ys_train, batch_size)
steps_per_epoch = len(X_train) // batch_size

# ==== STEP 6: Callbacks ====
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
checkpoint = ModelCheckpoint("gas_cylinder_model.keras", save_best_only=True, monitor='val_loss', verbose=1)

# ==== STEP 7: Train Model ====
history = model.fit(
    train_gen,
    steps_per_epoch=steps_per_epoch,
    validation_data=(X_val, {'brand_output': yb_val, 'size_output': ys_val}),
    epochs=100000,
    callbacks=[early_stop, checkpoint],
    verbose=1
)

print("Best model saved as gas_cylinder_model.keras")

# ==== STEP 8: Evaluate Model ====
val_loss, val_brand_loss, val_size_loss, val_brand_acc, val_size_acc = model.evaluate(
    X_val, {'brand_output': yb_val, 'size_output': ys_val}, verbose=1
)

print(f"\nFinal Validation Accuracy:")
print(f"Brand Accuracy: {val_brand_acc * 100:.2f}%")
print(f"Size Accuracy : {val_size_acc * 100:.2f}%")
# Out:
# Loading data...
# Total images loaded: 4702
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)    │ (None, 64, 64, 3)         │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_3 (Conv2D)             │ (None, 64, 64, 32)        │             896 │ input_layer_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_3         │ (None, 64, 64, 32)        │             128 │ conv2d_3[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_3               │ (None, 32, 32, 32)        │               0 │ batch_normalization_3[0][… │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_4 (Conv2D)             │ (None, 32, 32, 64)        │          18,496 │ max_pooling2d_3[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_4         │ (None, 32, 32, 64)        │             256 │ conv2d_4[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_4               │ (None, 16, 16, 64)        │               0 │ batch_normalization_4[0][… │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_5 (Conv2D)             │ (None, 16, 16, 128)       │          73,856 │ max_pooling2d_4[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_5         │ (None, 16, 16, 128)       │             512 │ conv2d_5[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_5               │ (None, 8, 8, 128)         │               0 │ batch_normalization_5[0][… │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten_1 (Flatten)           │ (None, 8192)              │               0 │ max_pooling2d_5[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_1 (Dropout)           │ (None, 8192)              │               0 │ flatten_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ brand_output (Dense)          │ (None, 2)                 │          16,386 │ dropout_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ size_output (Dense)           │ (None, 3)                 │          24,579 │ dropout_1[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 135,109 (527.77 KB)
#  Trainable params: 134,661 (526.02 KB)
#  Non-trainable params: 448 (1.75 KB)
# Epoch 1/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - brand_output_accuracy: 0.9601 - brand_output_loss: 0.2599 - loss: 1.9855 - size_output_accuracy: 0.5218 - size_output_loss: 1.7256
# Epoch 1: val_loss improved from inf to 19.18067, saving model to gas_cylinder_model.keras
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 59s 343ms/step - brand_output_accuracy: 0.9604 - brand_output_loss: 0.2586 - loss: 1.9827 - size_output_accuracy: 0.5219 - size_output_loss: 1.7240 - val_brand_output_accuracy: 0.0064 - val_brand_output_loss: 12.8145 - val_loss: 19.1807 - val_size_output_accuracy: 0.0021 - val_size_output_loss: 6.3767
# Epoch 2/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - brand_output_accuracy: 0.9939 - brand_output_loss: 0.0220 - loss: 1.4968 - size_output_accuracy: 0.5246 - size_output_loss: 1.4717
# Epoch 2: val_loss improved from 19.18067 to 4.49287, saving model to gas_cylinder_model.keras
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 38s 323ms/step - brand_output_accuracy: 0.9939 - brand_output_loss: 0.0221 - loss: 1.4980 - size_output_accuracy: 0.5245 - size_output_loss: 1.4728 - val_brand_output_accuracy: 0.1063 - val_brand_output_loss: 2.8250 - val_loss: 4.4929 - val_size_output_accuracy: 0.1350 - val_size_output_loss: 1.6779
# Epoch 3/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - brand_output_accuracy: 0.9965 - brand_output_loss: 0.0281 - loss: 1.5388 - size_output_accuracy: 0.5302 - size_output_loss: 1.5128
# Epoch 3: val_loss improved from 4.49287 to 1.82199, saving model to gas_cylinder_model.keras
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 37s 314ms/step - brand_output_accuracy: 0.9965 - brand_output_loss: 0.0281 - loss: 1.5385 - size_output_accuracy: 0.5301 - size_output_loss: 1.5125 - val_brand_output_accuracy: 0.9915 - val_brand_output_loss: 0.0661 - val_loss: 1.8220 - val_size_output_accuracy: 0.3294 - val_size_output_loss: 1.7529
# Epoch 4/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - brand_output_accuracy: 0.9944 - brand_output_loss: 0.0533 - loss: 1.4041 - size_output_accuracy: 0.5274 - size_output_loss: 1.3521
# Epoch 4: val_loss improved from 1.82199 to 1.33210, saving model to gas_cylinder_model.keras
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 37s 319ms/step - brand_output_accuracy: 0.9944 - brand_output_loss: 0.0534 - loss: 1.4036 - size_output_accuracy: 0.5274 - size_output_loss: 1.3515 - val_brand_output_accuracy: 0.8905 - val_brand_output_loss: 0.2789 - val_loss: 1.3321 - val_size_output_accuracy: 0.2179 - val_size_output_loss: 1.0612
# Epoch 5/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - brand_output_accuracy: 0.9918 - brand_output_loss: 0.0327 - loss: 1.2941 - size_output_accuracy: 0.5017 - size_output_loss: 1.2633
# Epoch 5: val_loss improved from 1.33210 to 1.14334, saving model to gas_cylinder_model.keras
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 37s 317ms/step - brand_output_accuracy: 0.9918 - brand_output_loss: 0.0328 - loss: 1.2937 - size_output_accuracy: 0.5018 - size_output_loss: 1.2629 - val_brand_output_accuracy: 0.9968 - val_brand_output_loss: 0.0171 - val_loss: 1.1433 - val_size_output_accuracy: 0.3464 - val_size_output_loss: 1.1263
# Epoch 6/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - brand_output_accuracy: 0.9938 - brand_output_loss: 0.0443 - loss: 1.1339 - size_output_accuracy: 0.5420 - size_output_loss: 1.0945
# Epoch 6: val_loss improved from 1.14334 to 0.96008, saving model to gas_cylinder_model.keras
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 37s 318ms/step - brand_output_accuracy: 0.9938 - brand_output_loss: 0.0441 - loss: 1.1338 - size_output_accuracy: 0.5420 - size_output_loss: 1.0945 - val_brand_output_accuracy: 0.9947 - val_brand_output_loss: 0.0228 - val_loss: 0.9601 - val_size_output_accuracy: 0.5994 - val_size_output_loss: 0.9386
# Epoch 7/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - brand_output_accuracy: 0.9943 - brand_output_loss: 0.0246 - loss: 1.1456 - size_output_accuracy: 0.5247 - size_output_loss: 1.1226
# Epoch 7: val_loss did not improve from 0.96008
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 37s 313ms/step - brand_output_accuracy: 0.9943 - brand_output_loss: 0.0247 - loss: 1.1457 - size_output_accuracy: 0.5246 - size_output_loss: 1.1226 - val_brand_output_accuracy: 0.9936 - val_brand_output_loss: 0.0866 - val_loss: 1.2468 - val_size_output_accuracy: 0.5983 - val_size_output_loss: 1.1611
# Epoch 8/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - brand_output_accuracy: 0.9956 - brand_output_loss: 0.0280 - loss: 1.1855 - size_output_accuracy: 0.5193 - size_output_loss: 1.1533
# Epoch 8: val_loss did not improve from 0.96008
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 38s 322ms/step - brand_output_accuracy: 0.9956 - brand_output_loss: 0.0280 - loss: 1.1854 - size_output_accuracy: 0.5192 - size_output_loss: 1.1532 - val_brand_output_accuracy: 0.9957 - val_brand_output_loss: 0.0065 - val_loss: 0.9610 - val_size_output_accuracy: 0.6004 - val_size_output_loss: 0.9546
# Epoch 9/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - brand_output_accuracy: 0.9943 - brand_output_loss: 0.0231 - loss: 1.0203 - size_output_accuracy: 0.5401 - size_output_loss: 0.9991
# Epoch 9: val_loss improved from 0.96008 to 0.80795, saving model to gas_cylinder_model.keras
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 38s 321ms/step - brand_output_accuracy: 0.9943 - brand_output_loss: 0.0231 - loss: 1.0201 - size_output_accuracy: 0.5401 - size_output_loss: 0.9989 - val_brand_output_accuracy: 0.9915 - val_brand_output_loss: 0.0339 - val_loss: 0.8080 - val_size_output_accuracy: 0.5940 - val_size_output_loss: 0.7742
# Epoch 10/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - brand_output_accuracy: 0.9952 - brand_output_loss: 0.0130 - loss: 0.9631 - size_output_accuracy: 0.5438 - size_output_loss: 0.9484
# Epoch 10: val_loss improved from 0.80795 to 0.72784, saving model to gas_cylinder_model.keras
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 36s 309ms/step - brand_output_accuracy: 0.9953 - brand_output_loss: 0.0131 - loss: 0.9632 - size_output_accuracy: 0.5438 - size_output_loss: 0.9484 - val_brand_output_accuracy: 0.9979 - val_brand_output_loss: 0.0278 - val_loss: 0.7278 - val_size_output_accuracy: 0.5951 - val_size_output_loss: 0.6987
# Epoch 11/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - brand_output_accuracy: 0.9948 - brand_output_loss: 0.0184 - loss: 0.9861 - size_output_accuracy: 0.5385 - size_output_loss: 0.9636
# Epoch 11: val_loss improved from 0.72784 to 0.65704, saving model to gas_cylinder_model.keras
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 37s 316ms/step - brand_output_accuracy: 0.9948 - brand_output_loss: 0.0185 - loss: 0.9866 - size_output_accuracy: 0.5384 - size_output_loss: 0.9641 - val_brand_output_accuracy: 0.9979 - val_brand_output_loss: 0.0245 - val_loss: 0.6570 - val_size_output_accuracy: 0.6312 - val_size_output_loss: 0.6329
# Epoch 12/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - brand_output_accuracy: 0.9989 - brand_output_loss: 0.0073 - loss: 1.0072 - size_output_accuracy: 0.5393 - size_output_loss: 1.0001
# Epoch 12: val_loss did not improve from 0.65704
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 36s 310ms/step - brand_output_accuracy: 0.9989 - brand_output_loss: 0.0074 - loss: 1.0070 - size_output_accuracy: 0.5392 - size_output_loss: 0.9999 - val_brand_output_accuracy: 0.9894 - val_brand_output_loss: 0.0442 - val_loss: 1.2670 - val_size_output_accuracy: 0.0117 - val_size_output_loss: 1.2216
# Epoch 13/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - brand_output_accuracy: 0.9960 - brand_output_loss: 0.0108 - loss: 0.9659 - size_output_accuracy: 0.4944 - size_output_loss: 0.9507
# Epoch 13: val_loss did not improve from 0.65704
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 38s 322ms/step - brand_output_accuracy: 0.9960 - brand_output_loss: 0.0109 - loss: 0.9657 - size_output_accuracy: 0.4946 - size_output_loss: 0.9505 - val_brand_output_accuracy: 0.8225 - val_brand_output_loss: 0.4828 - val_loss: 1.1386 - val_size_output_accuracy: 0.5940 - val_size_output_loss: 0.6610
# Epoch 14/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - brand_output_accuracy: 0.9958 - brand_output_loss: 0.0183 - loss: 0.9096 - size_output_accuracy: 0.5401 - size_output_loss: 0.8915
# Epoch 14: val_loss did not improve from 0.65704
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 37s 317ms/step - brand_output_accuracy: 0.9958 - brand_output_loss: 0.0183 - loss: 0.9097 - size_output_accuracy: 0.5402 - size_output_loss: 0.8916 - val_brand_output_accuracy: 0.9957 - val_brand_output_loss: 0.0335 - val_loss: 1.0066 - val_size_output_accuracy: 0.1753 - val_size_output_loss: 0.9699
# Epoch 15/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - brand_output_accuracy: 0.9971 - brand_output_loss: 0.0108 - loss: 0.9640 - size_output_accuracy: 0.5227 - size_output_loss: 0.9491
# Epoch 15: val_loss did not improve from 0.65704
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 36s 312ms/step - brand_output_accuracy: 0.9971 - brand_output_loss: 0.0109 - loss: 0.9639 - size_output_accuracy: 0.5228 - size_output_loss: 0.9490 - val_brand_output_accuracy: 0.9989 - val_brand_output_loss: 0.0201 - val_loss: 0.9471 - val_size_output_accuracy: 0.4198 - val_size_output_loss: 0.9246
# Epoch 16/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - brand_output_accuracy: 0.9966 - brand_output_loss: 0.0154 - loss: 0.9821 - size_output_accuracy: 0.5379 - size_output_loss: 0.9644
# Epoch 16: val_loss did not improve from 0.65704
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 36s 311ms/step - brand_output_accuracy: 0.9966 - brand_output_loss: 0.0154 - loss: 0.9825 - size_output_accuracy: 0.5378 - size_output_loss: 0.9648 - val_brand_output_accuracy: 0.9979 - val_brand_output_loss: 0.0138 - val_loss: 0.7286 - val_size_output_accuracy: 0.6281 - val_size_output_loss: 0.7158
# Epoch 17/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - brand_output_accuracy: 0.9976 - brand_output_loss: 0.0090 - loss: 0.8914 - size_output_accuracy: 0.5469 - size_output_loss: 0.8823
# Epoch 17: val_loss did not improve from 0.65704
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 37s 318ms/step - brand_output_accuracy: 0.9976 - brand_output_loss: 0.0090 - loss: 0.8915 - size_output_accuracy: 0.5468 - size_output_loss: 0.8824 - val_brand_output_accuracy: 0.9979 - val_brand_output_loss: 0.0109 - val_loss: 0.7490 - val_size_output_accuracy: 0.5367 - val_size_output_loss: 0.7377
# Epoch 18/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - brand_output_accuracy: 0.9974 - brand_output_loss: 0.0144 - loss: 0.8668 - size_output_accuracy: 0.5456 - size_output_loss: 0.8527
# Epoch 18: val_loss did not improve from 0.65704
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 37s 317ms/step - brand_output_accuracy: 0.9974 - brand_output_loss: 0.0144 - loss: 0.8667 - size_output_accuracy: 0.5456 - size_output_loss: 0.8526 - val_brand_output_accuracy: 0.8704 - val_brand_output_loss: 0.3194 - val_loss: 0.9675 - val_size_output_accuracy: 0.5940 - val_size_output_loss: 0.6515
# Epoch 19/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - brand_output_accuracy: 0.9955 - brand_output_loss: 0.0099 - loss: 0.8551 - size_output_accuracy: 0.5342 - size_output_loss: 0.8497
# Epoch 19: val_loss did not improve from 0.65704
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 34s 293ms/step - brand_output_accuracy: 0.9955 - brand_output_loss: 0.0099 - loss: 0.8553 - size_output_accuracy: 0.5342 - size_output_loss: 0.8499 - val_brand_output_accuracy: 0.9989 - val_brand_output_loss: 0.0160 - val_loss: 1.4472 - val_size_output_accuracy: 0.3889 - val_size_output_loss: 1.4298
# Epoch 20/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - brand_output_accuracy: 0.9931 - brand_output_loss: 0.0219 - loss: 0.9050 - size_output_accuracy: 0.5444 - size_output_loss: 0.8836
# Epoch 20: val_loss did not improve from 0.65704
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 31s 267ms/step - brand_output_accuracy: 0.9931 - brand_output_loss: 0.0218 - loss: 0.9046 - size_output_accuracy: 0.5445 - size_output_loss: 0.8833 - val_brand_output_accuracy: 0.9904 - val_brand_output_loss: 0.0320 - val_loss: 0.6718 - val_size_output_accuracy: 0.6047 - val_size_output_loss: 0.6397
# Epoch 21/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - brand_output_accuracy: 0.9974 - brand_output_loss: 0.0113 - loss: 0.8477 - size_output_accuracy: 0.5218 - size_output_loss: 0.8351
# Epoch 21: val_loss improved from 0.65704 to 0.64255, saving model to gas_cylinder_model.keras
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 31s 268ms/step - brand_output_accuracy: 0.9974 - brand_output_loss: 0.0113 - loss: 0.8475 - size_output_accuracy: 0.5219 - size_output_loss: 0.8349 - val_brand_output_accuracy: 0.9989 - val_brand_output_loss: 0.0118 - val_loss: 0.6426 - val_size_output_accuracy: 0.6557 - val_size_output_loss: 0.6312
# Epoch 22/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - brand_output_accuracy: 0.9977 - brand_output_loss: 0.0071 - loss: 0.8112 - size_output_accuracy: 0.5354 - size_output_loss: 0.8047
# Epoch 22: val_loss did not improve from 0.64255
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 37s 313ms/step - brand_output_accuracy: 0.9977 - brand_output_loss: 0.0071 - loss: 0.8116 - size_output_accuracy: 0.5353 - size_output_loss: 0.8051 - val_brand_output_accuracy: 0.9979 - val_brand_output_loss: 0.0142 - val_loss: 0.7816 - val_size_output_accuracy: 0.5940 - val_size_output_loss: 0.7682
# Epoch 23/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - brand_output_accuracy: 0.9977 - brand_output_loss: 0.0062 - loss: 0.7939 - size_output_accuracy: 0.5628 - size_output_loss: 0.7877
# Epoch 23: val_loss did not improve from 0.64255
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 36s 311ms/step - brand_output_accuracy: 0.9977 - brand_output_loss: 0.0062 - loss: 0.7938 - size_output_accuracy: 0.5628 - size_output_loss: 0.7876 - val_brand_output_accuracy: 0.9968 - val_brand_output_loss: 0.0114 - val_loss: 0.7234 - val_size_output_accuracy: 0.5951 - val_size_output_loss: 0.7127
# Epoch 24/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - brand_output_accuracy: 0.9980 - brand_output_loss: 0.0079 - loss: 0.8361 - size_output_accuracy: 0.5336 - size_output_loss: 0.8309
# Epoch 24: val_loss did not improve from 0.64255
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 36s 312ms/step - brand_output_accuracy: 0.9980 - brand_output_loss: 0.0079 - loss: 0.8362 - size_output_accuracy: 0.5335 - size_output_loss: 0.8310 - val_brand_output_accuracy: 0.9968 - val_brand_output_loss: 0.0097 - val_loss: 0.7987 - val_size_output_accuracy: 0.5951 - val_size_output_loss: 0.7884
# Epoch 25/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - brand_output_accuracy: 0.9975 - brand_output_loss: 0.0077 - loss: 0.8383 - size_output_accuracy: 0.5321 - size_output_loss: 0.8303
# Epoch 25: val_loss did not improve from 0.64255
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 36s 311ms/step - brand_output_accuracy: 0.9975 - brand_output_loss: 0.0077 - loss: 0.8382 - size_output_accuracy: 0.5321 - size_output_loss: 0.8302 - val_brand_output_accuracy: 0.9947 - val_brand_output_loss: 0.0201 - val_loss: 0.7671 - val_size_output_accuracy: 0.5972 - val_size_output_loss: 0.7473
# Epoch 26/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - brand_output_accuracy: 0.9978 - brand_output_loss: 0.0120 - loss: 0.8319 - size_output_accuracy: 0.5432 - size_output_loss: 0.8183
# Epoch 26: val_loss did not improve from 0.64255
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 37s 314ms/step - brand_output_accuracy: 0.9978 - brand_output_loss: 0.0120 - loss: 0.8318 - size_output_accuracy: 0.5432 - size_output_loss: 0.8182 - val_brand_output_accuracy: 0.9989 - val_brand_output_loss: 0.0119 - val_loss: 0.6822 - val_size_output_accuracy: 0.5940 - val_size_output_loss: 0.6704
# Epoch 27/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - brand_output_accuracy: 0.9956 - brand_output_loss: 0.0099 - loss: 0.8112 - size_output_accuracy: 0.5463 - size_output_loss: 0.8013
# Epoch 27: val_loss did not improve from 0.64255
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 37s 319ms/step - brand_output_accuracy: 0.9956 - brand_output_loss: 0.0099 - loss: 0.8111 - size_output_accuracy: 0.5463 - size_output_loss: 0.8012 - val_brand_output_accuracy: 0.9979 - val_brand_output_loss: 0.0096 - val_loss: 0.7727 - val_size_output_accuracy: 0.5962 - val_size_output_loss: 0.7631
# Epoch 28/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - brand_output_accuracy: 0.9976 - brand_output_loss: 0.0069 - loss: 0.7945 - size_output_accuracy: 0.5582 - size_output_loss: 0.7885
# Epoch 28: val_loss did not improve from 0.64255
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 37s 316ms/step - brand_output_accuracy: 0.9976 - brand_output_loss: 0.0069 - loss: 0.7946 - size_output_accuracy: 0.5583 - size_output_loss: 0.7886 - val_brand_output_accuracy: 0.9979 - val_brand_output_loss: 0.0056 - val_loss: 0.6551 - val_size_output_accuracy: 0.5962 - val_size_output_loss: 0.6496
# Epoch 29/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - brand_output_accuracy: 0.9984 - brand_output_loss: 0.0046 - loss: 0.7520 - size_output_accuracy: 0.5622 - size_output_loss: 0.7463
# Epoch 29: val_loss improved from 0.64255 to 0.51591, saving model to gas_cylinder_model.keras
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 38s 326ms/step - brand_output_accuracy: 0.9984 - brand_output_loss: 0.0047 - loss: 0.7521 - size_output_accuracy: 0.5622 - size_output_loss: 0.7464 - val_brand_output_accuracy: 0.9989 - val_brand_output_loss: 0.0084 - val_loss: 0.5159 - val_size_output_accuracy: 0.6259 - val_size_output_loss: 0.5074
# Epoch 30/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - brand_output_accuracy: 0.9971 - brand_output_loss: 0.0083 - loss: 0.8048 - size_output_accuracy: 0.5473 - size_output_loss: 0.7970
# Epoch 30: val_loss did not improve from 0.51591
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 37s 313ms/step - brand_output_accuracy: 0.9971 - brand_output_loss: 0.0083 - loss: 0.8048 - size_output_accuracy: 0.5472 - size_output_loss: 0.7970 - val_brand_output_accuracy: 0.9979 - val_brand_output_loss: 0.0055 - val_loss: 0.5861 - val_size_output_accuracy: 0.7216 - val_size_output_loss: 0.5805
# Epoch 31/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - brand_output_accuracy: 0.9981 - brand_output_loss: 0.0043 - loss: 0.7928 - size_output_accuracy: 0.5407 - size_output_loss: 0.7882
# Epoch 31: val_loss did not improve from 0.51591
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 37s 312ms/step - brand_output_accuracy: 0.9981 - brand_output_loss: 0.0043 - loss: 0.7927 - size_output_accuracy: 0.5407 - size_output_loss: 0.7881 - val_brand_output_accuracy: 0.9968 - val_brand_output_loss: 0.0071 - val_loss: 0.6323 - val_size_output_accuracy: 0.7269 - val_size_output_loss: 0.6251
# Epoch 32/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - brand_output_accuracy: 0.9962 - brand_output_loss: 0.0092 - loss: 0.7541 - size_output_accuracy: 0.5548 - size_output_loss: 0.7448
# Epoch 32: val_loss did not improve from 0.51591
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 37s 316ms/step - brand_output_accuracy: 0.9962 - brand_output_loss: 0.0092 - loss: 0.7542 - size_output_accuracy: 0.5548 - size_output_loss: 0.7449 - val_brand_output_accuracy: 0.9989 - val_brand_output_loss: 0.0046 - val_loss: 0.5854 - val_size_output_accuracy: 0.6047 - val_size_output_loss: 0.5810
# Epoch 33/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - brand_output_accuracy: 0.9986 - brand_output_loss: 0.0070 - loss: 0.7728 - size_output_accuracy: 0.5487 - size_output_loss: 0.7659
# Epoch 33: val_loss did not improve from 0.51591
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 37s 317ms/step - brand_output_accuracy: 0.9986 - brand_output_loss: 0.0070 - loss: 0.7727 - size_output_accuracy: 0.5486 - size_output_loss: 0.7658 - val_brand_output_accuracy: 0.9979 - val_brand_output_loss: 0.0042 - val_loss: 0.7163 - val_size_output_accuracy: 0.5940 - val_size_output_loss: 0.7128
# Epoch 34/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - brand_output_accuracy: 0.9986 - brand_output_loss: 0.0047 - loss: 0.7501 - size_output_accuracy: 0.5616 - size_output_loss: 0.7456
# Epoch 34: val_loss did not improve from 0.51591
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 38s 327ms/step - brand_output_accuracy: 0.9986 - brand_output_loss: 0.0047 - loss: 0.7502 - size_output_accuracy: 0.5615 - size_output_loss: 0.7457 - val_brand_output_accuracy: 0.9989 - val_brand_output_loss: 0.0064 - val_loss: 0.7531 - val_size_output_accuracy: 0.6047 - val_size_output_loss: 0.7470
# Epoch 35/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - brand_output_accuracy: 1.0000 - brand_output_loss: 0.0013 - loss: 0.7330 - size_output_accuracy: 0.5668 - size_output_loss: 0.7320
# Epoch 35: val_loss did not improve from 0.51591
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 38s 322ms/step - brand_output_accuracy: 1.0000 - brand_output_loss: 0.0013 - loss: 0.7331 - size_output_accuracy: 0.5668 - size_output_loss: 0.7321 - val_brand_output_accuracy: 0.9979 - val_brand_output_loss: 0.0033 - val_loss: 1.1277 - val_size_output_accuracy: 0.1275 - val_size_output_loss: 1.1241
# Epoch 36/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - brand_output_accuracy: 0.9991 - brand_output_loss: 0.0042 - loss: 0.7699 - size_output_accuracy: 0.5439 - size_output_loss: 0.7661
# Epoch 36: val_loss did not improve from 0.51591
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 38s 323ms/step - brand_output_accuracy: 0.9991 - brand_output_loss: 0.0042 - loss: 0.7698 - size_output_accuracy: 0.5441 - size_output_loss: 0.7659 - val_brand_output_accuracy: 0.9968 - val_brand_output_loss: 0.0079 - val_loss: 0.6066 - val_size_output_accuracy: 0.6631 - val_size_output_loss: 0.5987
# Epoch 37/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - brand_output_accuracy: 0.9976 - brand_output_loss: 0.0125 - loss: 0.7402 - size_output_accuracy: 0.5723 - size_output_loss: 0.7281
# Epoch 37: val_loss did not improve from 0.51591
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 37s 315ms/step - brand_output_accuracy: 0.9976 - brand_output_loss: 0.0125 - loss: 0.7402 - size_output_accuracy: 0.5721 - size_output_loss: 0.7282 - val_brand_output_accuracy: 0.9989 - val_brand_output_loss: 0.0056 - val_loss: 0.6857 - val_size_output_accuracy: 0.6015 - val_size_output_loss: 0.6796
# Epoch 38/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - brand_output_accuracy: 0.9966 - brand_output_loss: 0.0095 - loss: 0.7487 - size_output_accuracy: 0.5606 - size_output_loss: 0.7391
# Epoch 38: val_loss did not improve from 0.51591
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 37s 317ms/step - brand_output_accuracy: 0.9966 - brand_output_loss: 0.0094 - loss: 0.7488 - size_output_accuracy: 0.5605 - size_output_loss: 0.7392 - val_brand_output_accuracy: 0.9989 - val_brand_output_loss: 0.0044 - val_loss: 0.7803 - val_size_output_accuracy: 0.1849 - val_size_output_loss: 0.7753
# Epoch 39/100000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - brand_output_accuracy: 0.9978 - brand_output_loss: 0.0082 - loss: 0.7572 - size_output_accuracy: 0.5401 - size_output_loss: 0.7488
# Epoch 39: val_loss did not improve from 0.51591
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 37s 316ms/step - brand_output_accuracy: 0.9978 - brand_output_loss: 0.0082 - loss: 0.7571 - size_output_accuracy: 0.5403 - size_output_loss: 0.7487 - val_brand_output_accuracy: 0.9989 - val_brand_output_loss: 0.0040 - val_loss: 0.7177 - val_size_output_accuracy: 0.5940 - val_size_output_loss: 0.7143
# Best model saved as gas_cylinder_model.keras
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - brand_output_accuracy: 0.9987 - brand_output_loss: 0.0106 - loss: 0.5429 - size_output_accuracy: 0.6102 - size_output_loss: 0.5322
#
# Final Validation Accuracy:
# Brand Accuracy: 99.89%
# Size Accuracy : 62.59%

# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
import tensorflow as tf
from PIL import Image

# 1. Create dataframe from folder structure
base_path = r'C:\Users\kunjc\Downloads\gas'

data = []
for folder in os.listdir(base_path):
    folder_path = os.path.join(base_path, folder)
    if os.path.isdir(folder_path):
        brand, size = folder.split('_')
        for file in os.listdir(folder_path):
            if file.lower().endswith(('.jpg', '.png', '.jpeg')):
                data.append({
                    'filepath': os.path.join(folder_path, file),
                    'brand': brand.upper(),
                    'size': size.upper()
                })

df = pd.DataFrame(data)

# 2. Label encoding
df['brand'] = df['brand'].map({'HP': 0, 'INDANE': 1})
df['size'] = df['size'].map({'2KG': 0, '5KG': 1, '15KG': 2})

# 3. Filter out classes with fewer than 2 samples
counts = df.groupby(['brand', 'size']).size().reset_index(name='count')
valid_combos = counts[counts['count'] >= 2][['brand', 'size']]
df_filtered = df.merge(valid_combos, on=['brand', 'size'])

# 4. Train-validation split (with stratify)
train_df, val_df = train_test_split(
    df_filtered,
    test_size=0.2,
    random_state=42,
    stratify=df_filtered[['brand', 'size']]
)

# 5. ImageDataGenerator
img_size = (128, 128)
batch_size = 32

def create_generator(df, datagen):
    return datagen.flow_from_dataframe(
        df,
        x_col='filepath',
        y_col=['brand', 'size'],
        target_size=img_size,
        class_mode='multi_output',
        batch_size=batch_size,
        shuffle=True
    )

# Keras doesn't support multi-output natively in flow_from_dataframe, so use custom generator
class MultiOutputDataGenerator(tf.keras.utils.Sequence):
    def __init__(self, df, datagen, batch_size, img_size, shuffle=True):
        self.df = df.reset_index(drop=True)
        self.datagen = datagen
        self.batch_size = batch_size
        self.img_size = img_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(self.df))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.df) / self.batch_size))

    def __getitem__(self, index):
        batch_indices = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        batch_df = self.df.iloc[batch_indices]

        X = np.zeros((len(batch_df), *self.img_size, 3))
        brand_labels = np.zeros((len(batch_df), 1))
        size_labels = np.zeros((len(batch_df), 1))

        for i, row in enumerate(batch_df.itertuples()):
            img = Image.open(row.filepath).resize(self.img_size).convert('RGB')
            img = np.array(img) / 255.0
            X[i] = img
            brand_labels[i] = row.brand
            size_labels[i] = row.size

        return X, {'brand_output': brand_labels, 'size_output': size_labels}

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indexes)

datagen = ImageDataGenerator()

train_gen = MultiOutputDataGenerator(train_df, datagen, batch_size, img_size)
val_gen = MultiOutputDataGenerator(val_df, datagen, batch_size, img_size, shuffle=False)

# 6. Model architecture (Multi-output CNN)
input_layer = Input(shape=(*img_size, 3))
x = Conv2D(32, (3,3), activation='relu')(input_layer)
x = MaxPooling2D((2,2))(x)
x = Conv2D(64, (3,3), activation='relu')(x)
x = MaxPooling2D((2,2))(x)
x = Flatten()(x)
x = Dropout(0.5)(x)

# Branch 1: Brand (HP vs INDANE)
brand_output = Dense(1, activation='sigmoid', name='brand_output')(x)

# Branch 2: Size (2KG, 5KG, 15KG)
size_output = Dense(3, activation='softmax', name='size_output')(x)

model = Model(inputs=input_layer, outputs=[brand_output, size_output])

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss={
        'brand_output': 'binary_crossentropy',
        'size_output': 'sparse_categorical_crossentropy'
    },
    metrics={
        'brand_output': 'accuracy',
        'size_output': 'accuracy'
    }
)

model.summary()

# 7. Train model
callbacks = [EarlyStopping(patience=5, restore_best_weights=True)]

history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=30,
    callbacks=callbacks
)

# 8. Save the model
model.save("gas_cylinder_model.keras")  # Modern format
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)    │ (None, 128, 128, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_17 (Conv2D)            │ (None, 126, 126, 32)      │             896 │ input_layer_6[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_17              │ (None, 63, 63, 32)        │               0 │ conv2d_17[0][0]            │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_18 (Conv2D)            │ (None, 61, 61, 64)        │          18,496 │ max_pooling2d_17[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_18              │ (None, 30, 30, 64)        │               0 │ conv2d_18[0][0]            │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten_6 (Flatten)           │ (None, 57600)             │               0 │ max_pooling2d_18[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_6 (Dropout)           │ (None, 57600)             │               0 │ flatten_6[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ brand_output (Dense)          │ (None, 1)                 │          57,601 │ dropout_6[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ size_output (Dense)           │ (None, 3)                 │         172,803 │ dropout_6[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 249,796 (975.77 KB)
#  Trainable params: 249,796 (975.77 KB)
#  Non-trainable params: 0 (0.00 B)
# C:\Users\kunjc\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 350s 3s/step - brand_output_accuracy: 0.9700 - brand_output_loss: 0.1010 - loss: 0.2467 - size_output_accuracy: 0.9489 - size_output_loss: 0.1446 - val_brand_output_accuracy: 0.9947 - val_brand_output_loss: 0.0123 - val_loss: 0.0180 - val_size_output_accuracy: 0.9979 - val_size_output_loss: 0.0054
# Epoch 2/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 377s 3s/step - brand_output_accuracy: 0.9959 - brand_output_loss: 0.0159 - loss: 0.0190 - size_output_accuracy: 0.9992 - size_output_loss: 0.0031 - val_brand_output_accuracy: 0.9968 - val_brand_output_loss: 0.0070 - val_loss: 0.0118 - val_size_output_accuracy: 0.9979 - val_size_output_loss: 0.0046
# Epoch 3/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 321s 3s/step - brand_output_accuracy: 0.9978 - brand_output_loss: 0.0063 - loss: 0.0092 - size_output_accuracy: 0.9998 - size_output_loss: 0.0028 - val_brand_output_accuracy: 0.9957 - val_brand_output_loss: 0.0070 - val_loss: 0.0126 - val_size_output_accuracy: 0.9979 - val_size_output_loss: 0.0054
# Epoch 4/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 335s 3s/step - brand_output_accuracy: 0.9995 - brand_output_loss: 0.0018 - loss: 0.0033 - size_output_accuracy: 0.9993 - size_output_loss: 0.0015 - val_brand_output_accuracy: 0.9979 - val_brand_output_loss: 0.0045 - val_loss: 0.0062 - val_size_output_accuracy: 0.9989 - val_size_output_loss: 0.0016
# Epoch 5/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 330s 3s/step - brand_output_accuracy: 0.9993 - brand_output_loss: 0.0014 - loss: 0.0015 - size_output_accuracy: 1.0000 - size_output_loss: 1.2894e-04 - val_brand_output_accuracy: 0.9989 - val_brand_output_loss: 0.0036 - val_loss: 0.0046 - val_size_output_accuracy: 0.9989 - val_size_output_loss: 8.5252e-04
# Epoch 6/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 324s 3s/step - brand_output_accuracy: 1.0000 - brand_output_loss: 4.0486e-04 - loss: 4.4016e-04 - size_output_accuracy: 1.0000 - size_output_loss: 4.1874e-05 - val_brand_output_accuracy: 0.9989 - val_brand_output_loss: 0.0033 - val_loss: 0.0057 - val_size_output_accuracy: 0.9989 - val_size_output_loss: 0.0023
# Epoch 7/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 328s 3s/step - brand_output_accuracy: 1.0000 - brand_output_loss: 8.2234e-05 - loss: 9.1398e-05 - size_output_accuracy: 1.0000 - size_output_loss: 9.1268e-06 - val_brand_output_accuracy: 0.9989 - val_brand_output_loss: 0.0031 - val_loss: 0.0054 - val_size_output_accuracy: 0.9989 - val_size_output_loss: 0.0022
# Epoch 8/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 341s 3s/step - brand_output_accuracy: 1.0000 - brand_output_loss: 8.2845e-05 - loss: 8.7995e-05 - size_output_accuracy: 1.0000 - size_output_loss: 4.6256e-06 - val_brand_output_accuracy: 0.9989 - val_brand_output_loss: 0.0028 - val_loss: 0.0053 - val_size_output_accuracy: 0.9989 - val_size_output_loss: 0.0024
# Epoch 9/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 325s 3s/step - brand_output_accuracy: 1.0000 - brand_output_loss: 9.4759e-05 - loss: 9.9768e-05 - size_output_accuracy: 1.0000 - size_output_loss: 4.9431e-06 - val_brand_output_accuracy: 0.9989 - val_brand_output_loss: 0.0033 - val_loss: 0.0061 - val_size_output_accuracy: 0.9989 - val_size_output_loss: 0.0027
# Epoch 10/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 316s 3s/step - brand_output_accuracy: 1.0000 - brand_output_loss: 3.3472e-05 - loss: 3.5414e-05 - size_output_accuracy: 1.0000 - size_output_loss: 1.8109e-06 - val_brand_output_accuracy: 0.9989 - val_brand_output_loss: 0.0028 - val_loss: 0.0055 - val_size_output_accuracy: 0.9989 - val_size_output_loss: 0.0026

# %%
import os
import numpy as np
from PIL import Image
from tensorflow.keras.models import load_model
from tqdm import tqdm

# === Paths ===
test_path = r'C:\Users\kunjc\Downloads\gas_test'  # Folder with test images
model_path = 'gas_cylinder_model.keras'
img_size = (128, 128)

# === Label maps (for prediction output) ===
inv_brand_map = {0: 'HP', 1: 'INDANE'}
inv_size_map = {0: '2KG', 1: '5KG', 2: '15KG'}

# === Load model ===
model = load_model(model_path)

# === Process and Predict ===
results = []

for file in tqdm(os.listdir(test_path)):
    if file.lower().endswith(('.jpg', '.jpeg', '.png')):
        try:
            img_path = os.path.join(test_path, file)
            img = Image.open(img_path).resize(img_size).convert('RGB')
            img_array = np.expand_dims(np.array(img) / 255.0, axis=0)

            brand_prob, size_prob = model.predict(img_array, verbose=0)
            brand_pred = int(brand_prob[0] > 0.5)
            size_pred = np.argmax(size_prob[0])

            results.append({
                'filename': file,
                'predicted_brand': inv_brand_map[brand_pred],
                'predicted_size': inv_size_map[size_pred]
            })

        except Exception as e:
            print(f"Error processing {file}: {e}")

# === Show predictions ===
import pandas as pd
df_results = pd.DataFrame(results)
print(df_results)

# === Optional: Save to CSV ===
df_results.to_csv("predictions_only.csv", index=False)
print("\n✅ Predictions saved to 'predictions_only.csv'")
# Out:
#   0%|                                                                                           | 0/12 [00:00<?, ?it/s]C:\Users\kunjc\AppData\Local\Temp\ipykernel_19164\264425509.py:30: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   brand_pred = int(brand_prob[0] > 0.5)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [00:01<00:00,  8.05it/s]
#       filename predicted_brand predicted_size
# 0    HP2.1.jpg              HP            2KG
# 1    HP2.2.jpg              HP            2KG
# 2      HP2.jpg              HP            2KG
# 3    HP5.1.jpg              HP            5KG
# 4    HP5.2.jpg              HP            5KG
# 5      HP5.jpg              HP            5KG
# 6   ID15.1.jpg          INDANE           15KG
# 7   ID15.2.jpg          INDANE           15KG
# 8     ID15.jpg          INDANE           15KG
# 9    ID5.1.jpg          INDANE            5KG
# 10   ID5.2.jpg          INDANE            5KG
# 11     ID5.jpg          INDANE            5KG
#
# ✅ Predictions saved to 'predictions_only.csv'

# %%
model.summary()
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)    │ (None, 128, 128, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_17 (Conv2D)            │ (None, 126, 126, 32)      │             896 │ input_layer_6[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_17              │ (None, 63, 63, 32)        │               0 │ conv2d_17[0][0]            │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_18 (Conv2D)            │ (None, 61, 61, 64)        │          18,496 │ max_pooling2d_17[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_18              │ (None, 30, 30, 64)        │               0 │ conv2d_18[0][0]            │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten_6 (Flatten)           │ (None, 57600)             │               0 │ max_pooling2d_18[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_6 (Dropout)           │ (None, 57600)             │               0 │ flatten_6[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ brand_output (Dense)          │ (None, 1)                 │          57,601 │ dropout_6[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ size_output (Dense)           │ (None, 3)                 │         172,803 │ dropout_6[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 749,390 (2.86 MB)
#  Trainable params: 249,796 (975.77 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 499,594 (1.91 MB)

# %%
venv\Scripts\activate
python app.py
http://127.0.0.1:5000
